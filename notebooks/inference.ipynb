# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
bs = 32 # batch size 8 for version 0, 32 for version 1
version = 0

# %%
from fastai import *
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path="/content/drive/MyDrive/Clothing Classifications/data"
dataloader_path="/content/drive/MyDrive/Clothing Classifications/dataloaders/clothings_dataloader_v7.pkl"
model_path="/content/drive/MyDrive/Clothing Classifications/models/clothing-recognizer-v9-resnet32-epoch3-bs32.pkl"

# %% [markdown]
# # Inference 1

# %%
model = load_learner(model_path)

# %%
img = Image.open('/content/download.jfif')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=89x128>

# %%
model.predict('/content/download.jfif')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Blazers;Upper Wear',
#  tensor(0),
#  tensor([9.9959e-01, 6.9758e-08, 1.2934e-05, 4.0508e-06, 9.0556e-06, 3.1260e-07,
#          9.0479e-07, 2.0241e-04, 1.0184e-04, 1.1848e-05, 3.8339e-05, 6.6407e-07,
#          1.8593e-05, 2.0384e-06, 5.9665e-06, 2.3223e-07, 4.8021e-06]))

# %% [markdown]
# # Inference 2

# %%
img = Image.open('/content/sample2.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict('/content/sample2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('T-Shirts;Upper Wear',
#  tensor(15),
#  tensor([2.5639e-05, 1.1630e-06, 1.0393e-04, 7.7444e-06, 2.0679e-05, 5.3280e-06,
#          5.4192e-05, 5.5354e-06, 5.9990e-05, 3.1157e-05, 8.4402e-06, 1.0210e-01,
#          2.3242e-04, 1.7441e-06, 1.2969e-03, 8.9600e-01, 5.0460e-05]))

# %% [markdown]
# # Inference 3

# %%
img = Image.open('/content/sample3.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict('/content/sample3.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Watches;Accessories',
#  tensor(16),
#  tensor([2.1777e-07, 7.9845e-07, 5.6557e-05, 8.5745e-06, 8.9086e-07, 2.0073e-07,
#          1.4724e-06, 9.9784e-08, 1.6105e-05, 1.5720e-05, 1.7108e-07, 6.9994e-07,
#          5.0391e-06, 5.2276e-06, 8.1061e-08, 1.2743e-06, 9.9989e-01]))

# %% [markdown]
# # Inference 4

# %%
img = Image.open('/content/sample4.JPG')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict('/content/sample4.JPG')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Formal Pants;Lower Wear',
#  tensor(2),
#  tensor([1.2024e-03, 6.9881e-05, 5.1905e-01, 4.4012e-06, 2.2216e-05, 1.2508e-05,
#          5.0929e-05, 1.1296e-05, 2.8737e-03, 4.7614e-01, 4.6794e-06, 1.9480e-06,
#          2.6151e-05, 4.9883e-04, 1.5809e-05, 1.0774e-05, 7.9376e-06]))
